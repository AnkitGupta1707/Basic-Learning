# %% [markdown]
# # Lecture-8
# ## pandas part-1

# %% [markdown]
# ### pandas
# pandas is an open source, BSD-licensed library providing high-performance,easy-to-use data structures and data analytic tools for the python programming language.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### DataFrame

# %%
df=pd.DataFrame(np.arange(0,20).reshape(5,4),index=['row1','row2','row3','row4','row5'],columns=['col1','col2','col3','col4'])

# %%
df.head()
#head pop up first five rows of the table
# Out:
#       col1  col2  col3  col4
# row1     0     1     2     3
# row2     4     5     6     7
# row3     8     9    10    11
# row4    12    13    14    15
# row5    16    17    18    19

# %%
df.to_csv("test1.csv")
# to generate an excel file

# %%
# Accessing the elements
# 1. .loc  2. .iloc
df.loc['row1']
# Out:
# col1    0
# col2    1
# col3    2
# col4    3
# Name: row1, dtype: int64

# %%
type(df.loc['row1'])
# Out:
# pandas.core.series.Series

# %%
# DataFrame has more than one columns or more than one rows.
# DataSeries has either one column or one row.
df.iloc[:,:]
# iloc wants the index of both rows and columns.
# Out:
#       col1  col2  col3  col4
# row1     0     1     2     3
# row2     4     5     6     7
# row3     8     9    10    11
# row4    12    13    14    15
# row5    16    17    18    19

# %%
df.iloc[0:2,0:3]
# Out:
#       col1  col2  col3
# row1     0     1     2
# row2     4     5     6

# %%
type(df.iloc[0:2,0:3])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### convert DataFrame into Array

# %%
df.iloc[:,1:].values
# Out:
# array([[ 1,  2,  3],
#        [ 5,  6,  7],
#        [ 9, 10, 11],
#        [13, 14, 15],
#        [17, 18, 19]])

# %%
df.iloc[:,1:].values.shape
# Out:
# (5, 3)

# %%
df['col1'].value_counts()
# Out:
# col1
# 0     1
# 4     1
# 8     1
# 12    1
# 16    1
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# col1    0
# col2    0
# col3    0
# col4    0
# dtype: int64

# %%
df['col1'].unique()
# Out:
# array([ 0,  4,  8, 12, 16])

# %%
df['col1']
# Out:
# row1     0
# row2     4
# row3     8
# row4    12
# row5    16
# Name: col1, dtype: int64

# %%
df[['col1','col2']]
# Out:
#       col1  col2
# row1     0     1
# row2     4     5
# row3     8     9
# row4    12    13
# row5    16    17
