# %% [markdown]
# # LECTURE-6
# ## PYTHON SET AND DICTIONARY

# %% [markdown]
# ## SET

# %% [markdown]
# A set is a unordered collection of elements and it doesn't allow duplicates.

# %%
s=set()
print(s)
print(type(s))
# Out:
# set()
# <class 'set'>

# %%
x={"ankit","rahul","rohit"}
print(x)
# Out:
# {'rahul', 'rohit', 'ankit'}

# %% [markdown]
# ### in-built functions

# %%
x.add("raj")

# %%
x
# Out:
# {'ankit', 'rahul', 'raj', 'rohit'}

# %% [markdown]
# #no indexind allowed

# %%
s={"ankit","rohit","rahul"}

# %%
s.intersection(x)
# Out:
# {'ankit', 'rahul', 'rohit'}

# %%
s.difference(x)
# Out:
# set()

# %%
x.difference(s)
# Out:
# {'raj'}

# %%
x.difference_update(s)

# %%
x
# Out:
# {'raj'}

# %% [markdown]
# ### Dictionary

# %% [markdown]
# it is a key value pair and unordered collection of elements.

# %%
dic={}

# %%
type(dic)
# Out:
# dict

# %%
dic={1,2,3,4}
type(dic)
# Out:
# set

# %%
d={"car1":"Audi","car2":"bmw",'car3':'farrari'}

# %%
d['car1']
# Out:
# 'Audi'

# %%
for i in d:
    print(i)
# Out:
# car1
# car2
# car3

# %%
for i in d.values():
    print(i)
# Out:
# Audi
# bmw
# farrari

# %%
for i in d.items():
    print(i)
# Out:
# ('car1', 'Audi')
# ('car2', 'bmw')
# ('car3', 'farrari')

# %%
for i in d:
    print(i," : ",d[i])
# Out:
# car1  :  Audi
# car2  :  bmw
# car3  :  farrari

# %%
d
# Out:
# {'car1': 'Audi', 'car2': 'bmw', 'car3': 'farrari'}

# %% [markdown]
# #add

# %%
d['car4']='mercedes'

# %%
d
# Out:
# {'car1': 'Audi', 'car2': 'bmw', 'car3': 'farrari', 'car4': 'mercedes'}

# %%
car1_model={'mercedes':1900}
car2_model={'audi':1930}
car3_model={'Bmw' :1927}
d1={'car1':car1_model,'car2':car2_model,'car3':car3_model}

# %%
type(d1)
# Out:
# dict

# %%
d1
# Out:
# {'car1': {'mercedes': 1900}, 'car2': {'audi': 1930}, 'car3': {'Bmw': 1927}}

# %%
d1['car1']
# Out:
# {'mercedes': 1900}

# %% [markdown]
# ### Tuple

# %% [markdown]
# tuple is basically a list which is immutable i.e. after assingning the values we can not make a changes in it.

# %%
T=()

# %%
type(T)
# Out:
# tuple

# %%
t=(1,2,"ankit")

# %%
t
# Out:
# (1, 2, 'ankit')

# %%
t[0]
# Out:
# 1

# %%
t[0]=3
# Out:
# ----------------------------------------------------------------
# TypeError                      Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 t[0]=3
#
# TypeError: 'tuple' object does not support item assignment

# %%
t=(3,"okay")

# %%
t
# Out:
# (3, 'okay')

# %%
# in-
